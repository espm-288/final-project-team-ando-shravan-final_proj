# %% [markdown]
# ## Accessing GBIF data with the Planetary Computer STAC API
#
# This notebook provides an example of accessing [Global Biodiversity Information Facility](https://planetarycomputer.microsoft.com/dataset/gbif) (GBIF) occurrence data from the Planetary Computer STAC API. Periodic snapshots of the data are stored in Parquet format.
#
# We'll use [Dask](https://docs.dask.org/en/latest/) to read the partitioned Parquet Dataset.

# %%
import pystac_client

catalog = pystac_client.Client.open(
    "https://planetarycomputer.microsoft.com/api/stac/v1",
)
search = catalog.search(collections=["gbif"])
items = search.get_all_items()
items = {x.id: x for x in items}
list(items)
# Out:
# ['gbif-2022-03-01',
#  'gbif-2022-02-01',
#  'gbif-2022-01-01',
#  'gbif-2021-12-01',
#  'gbif-2021-11-01',
#  'gbif-2021-10-01',
#  'gbif-2021-09-01',
#  'gbif-2021-08-01',
#  'gbif-2021-07-01',
#  'gbif-2021-06-01',
#  'gbif-2021-04-13']

# %% [markdown]
# We'll take the most recent item.

# %%
item = list(items.values())[0]
item
# Out:
# <Item id=gbif-2022-03-01>

# %% [markdown]
# As usual, you should sign the item before trying to load the data.

# %%
import planetary_computer

signed_asset = planetary_computer.sign(item).assets["data"]

# %%
import dask.dataframe as dd

df = dd.read_parquet(
    signed_asset.href,
    storage_options=signed_asset.extra_fields["table:storage_options"],
    dataset={"require_extension": None},
)
df
# Out:
# Dask DataFrame Structure:
#                  gbifid datasetkey occurrenceid kingdom  phylum   class   order  family   genus species infraspecificepithet taxonrank scientificname verbatimscientificname verbatimscientificnameauthorship countrycode locality stateprovince occurrencestatus individualcount publishingorgkey decimallatitude decimallongitude coordinateuncertaintyinmeters coordinateprecision elevation elevationaccuracy    depth depthaccuracy eventdate    day  month   year taxonkey specieskey basisofrecord institutioncode collectioncode catalognumber recordnumber identifiedby dateidentified license rightsholder recordedby typestatus establishmentmeans lastinterpreted mediatype   issue
# npartitions=1105
#                   int64     object       object  object  object  object  object  object  object  object               object    object         object                 object                           object      object   object        object           object           int32           object         float64          float64                       float64             float64   float64           float64  float64       float64    object  int32  int32  int32    int32      int32        object          object         object        object       object       object         object  object       object     object     object             object          object    object  object
#                     ...        ...          ...     ...     ...     ...     ...     ...     ...     ...                  ...       ...            ...                    ...                              ...         ...      ...           ...              ...             ...              ...             ...              ...                           ...                 ...       ...               ...      ...           ...       ...    ...    ...    ...      ...        ...           ...             ...            ...           ...          ...          ...            ...     ...          ...        ...        ...                ...             ...       ...     ...
# ...                 ...        ...          ...     ...     ...     ...     ...     ...     ...     ...                  ...       ...            ...                    ...                              ...         ...      ...           ...              ...             ...              ...             ...              ...                           ...                 ...       ...               ...      ...           ...       ...    ...    ...    ...      ...        ...           ...             ...            ...           ...          ...          ...            ...     ...          ...        ...        ...                ...             ...       ...     ...
#                     ...        ...          ...     ...     ...     ...     ...     ...     ...     ...                  ...       ...            ...                    ...                              ...         ...      ...           ...              ...             ...              ...             ...              ...                           ...                 ...       ...               ...      ...           ...       ...    ...    ...    ...      ...        ...           ...             ...            ...           ...          ...          ...            ...     ...          ...        ...        ...                ...             ...       ...     ...
#                     ...        ...          ...     ...     ...     ...     ...     ...     ...     ...                  ...       ...            ...                    ...                              ...         ...      ...           ...              ...             ...              ...             ...              ...                           ...                 ...       ...               ...      ...           ...       ...    ...    ...    ...      ...        ...           ...             ...            ...           ...          ...          ...            ...     ...          ...        ...        ...                ...             ...       ...     ...
# Dask Name: read-parquet, 1105 tasks

# %% [markdown]
# As indicated by `npartitions`, this Parquet dataset is made up of many individual parquet files. We can read in a specific partition with `.get_partition`

# %%
chunk = df.get_partition(0).compute()
chunk
# Out:
#              gbifid                            datasetkey  \
# 0        2434528850  4ce8e3f9-2546-4af1-b28d-e2eadf05dfd4
# 1        2434529777  4ce8e3f9-2546-4af1-b28d-e2eadf05dfd4
# 2        2434529745  4ce8e3f9-2546-4af1-b28d-e2eadf05dfd4
# 3        2434529880  4ce8e3f9-2546-4af1-b28d-e2eadf05dfd4
# 4        2434529956  4ce8e3f9-2546-4af1-b28d-e2eadf05dfd4
# ...             ...                                   ...
# 1487797  3474245978  40e69efe-e113-4eea-9363-0a8eec54cf38
# 1487798  3474047766  40e69efe-e113-4eea-9363-0a8eec54cf38
# 1487799  3474245982  40e69efe-e113-4eea-9363-0a8eec54cf38
# 1487800  3474047770  40e69efe-e113-4eea-9363-0a8eec54cf38
# 1487801  3474245986  40e69efe-e113-4eea-9363-0a8eec54cf38
#
#                                  occurrenceid   kingdom        phylum  \
# 0        0002cac3-f34d-4150-a255-2fbae15fa88d   Plantae  Tracheophyta
# 1        0007f5be-ff59-4744-8e18-9abe6a8dad62   Plantae  Tracheophyta
# 2        000a1936-3008-44f5-813f-a6c3469416bb   Plantae  Tracheophyta
# 3        000cc9b9-a730-4b28-accc-d8f9943acaea   Plantae     Bryophyta
# 4        000ebd11-5641-4f51-af20-fe65b88a2307   Plantae  Tracheophyta
# ...                                       ...       ...           ...
# 1487797  121ca327-f397-49f6-9e9b-24592d2fd07a  Animalia      Chordata
# 1487798  0cdf4b41-ed02-4f49-91e0-1a982286ad89  Animalia      Chordata
# 1487799  122b4c1a-6448-4f0a-87ed-192dbb3993e5  Animalia      Chordata
# 1487800  0d0cc2bf-770c-41b5-b166-8c9a3919f441  Animalia      Chordata
# 1487801  1242b23e-b97d-480d-b30e-a4c5c064d163  Animalia      Chordata
#
#                  class            order            family       genus  \
# 0           Liliopsida           Poales           Poaceae  Cymbopogon
# 1        Magnoliopsida         Lamiales  Scrophulariaceae  Eremophila
# 2           Liliopsida           Poales        Cyperaceae       Carex
# 3            Bryopsida          Bryales     Bartramiaceae  Philonotis
# 4        Magnoliopsida        Asterales        Asteraceae     Senecio
# ...                ...              ...               ...         ...
# 1487797           Aves     Anseriformes          Anatidae      Aythya
# 1487798           Aves  Charadriiformes    Haematopodidae  Haematopus
# 1487799           Aves     Anseriformes          Anatidae     Tadorna
# 1487800           Aves     Anseriformes          Anatidae        Anas
# 1487801           Aves     Anseriformes          Anatidae      Branta
#
#                        species  ...    identifiedby       dateidentified  \
# 0        Cymbopogon bombycinus  ...     Simon, B.K.  1986-01-01T00:00:00
# 1            Eremophila elderi  ...  Chinnock, R.J.  1994-06-23T00:00:00
# 2             Carex chlorantha  ...    Willis, J.H.  1949-08-01T00:00:00
# 3            Philonotis tenuis  ...     Stone, I.G.                 None
# 4        Senecio pinnatifolius  ...  Thompson, I.R.  2005-06-07T00:00:00
# ...                        ...  ...             ...                  ...
# 1487797          Aythya ferina  ...            None                 None
# 1487798  Haematopus ostralegus  ...            None                 None
# 1487799        Tadorna tadorna  ...            None                 None
# 1487800          Anas clypeata  ...            None                 None
# 1487801        Branta bernicla  ...            None                 None
#
#            license                 rightsholder    recordedby typestatus  \
# 0        CC_BY_4_0  Royal Botanic Gardens Board  Dietrich, A.       None
# 1        CC_BY_4_0  Royal Botanic Gardens Board      Tate, R.       None
# 2        CC_BY_4_0  Royal Botanic Gardens Board   Robbins, F.       None
# 3        CC_BY_4_0  Royal Botanic Gardens Board   Stone, I.G.       None
# 4        CC_BY_4_0  Royal Botanic Gardens Board  Finley, C.D.       None
# ...            ...                          ...           ...        ...
# 1487797  CC_BY_4_0                         None            ()       None
# 1487798  CC_BY_4_0                         None            ()       None
# 1487799  CC_BY_4_0                         None            ()       None
# 1487800  CC_BY_4_0                         None            ()       None
# 1487801  CC_BY_4_0                         None            ()       None
#
#         establishmentmeans           lastinterpreted mediatype  \
# 0                     None  2022-02-15T20:42:05.490Z        []
# 1                     None  2022-02-15T20:42:05.496Z        []
# 2                     None  2022-02-15T20:42:05.504Z        []
# 3                     None  2022-02-15T20:42:05.509Z        []
# 4                     None  2022-02-15T20:42:05.515Z        []
# ...                    ...                       ...       ...
# 1487797               None  2022-02-22T19:38:06.595Z        []
# 1487798               None  2022-02-22T19:38:00.459Z        []
# 1487799               None  2022-02-22T19:38:06.595Z        []
# 1487800               None  2022-02-22T19:38:00.460Z        []
# 1487801               None  2022-02-22T19:38:06.595Z        []
#
#                                                      issue
# 0        [INSTITUTION_MATCH_FUZZY, COLLECTION_MATCH_FUZZY]
# 1        [INSTITUTION_MATCH_FUZZY, COLLECTION_MATCH_FUZZY]
# 2        [INSTITUTION_MATCH_FUZZY, COLLECTION_MATCH_FUZZY]
# 3        [INSTITUTION_MATCH_FUZZY, COLLECTION_MATCH_FUZZY]
# 4        [INSTITUTION_MATCH_FUZZY, COLLECTION_MATCH_FUZZY]
# ...                                                    ...
# 1487797  [RECORDED_DATE_INVALID, GEODETIC_DATUM_ASSUMED...
# 1487798  [RECORDED_DATE_INVALID, GEODETIC_DATUM_ASSUMED...
# 1487799  [RECORDED_DATE_INVALID, GEODETIC_DATUM_ASSUMED...
# 1487800  [RECORDED_DATE_INVALID, GEODETIC_DATUM_ASSUMED...
# 1487801  [RECORDED_DATE_INVALID, GEODETIC_DATUM_ASSUMED...
#
# [1487802 rows x 50 columns]

# %% [markdown]
# To get a sense for the most commonly observed species, we'll group the dataset and get the count of each species.

# %%
chunk.groupby(["kingdom", "phylum", "class", "family", "genus"]).species.value_counts().sort_values(ascending=False).head(15)
# Out:
# kingdom   phylum      class           family           genus         species
# Animalia  Arthropoda  Arachnida       Lycosidae        Trochosa      Trochosa terricola          6601
#                                                        Pardosa       Pardosa pullata             6396
#                       Insecta         Nymphalidae      Aglais        Aglais urticae              6246
#                                       Pieridae         Gonepteryx    Gonepteryx rhamni           6223
#                       Arachnida       Linyphiidae      Erigone       Erigone atra                5914
#                       Insecta         Calopterygidae   Calopteryx    Calopteryx virgo            5692
#           Chordata    Actinopterygii  Scombridae       Katsuwonus    Katsuwonus pelamis          5425
#           Arthropoda  Insecta         Coenagrionidae   Ischnura      Ischnura elegans            5315
#                       Arachnida       Lycosidae        Piratula      Piratula hygrophila         5304
#                                       Linyphiidae      Tenuiphantes  Tenuiphantes zimmermanni    5114
#                       Insecta         Platycnemididae  Platycnemis   Platycnemis pennipes        5066
#                       Arachnida       Linyphiidae      Bathyphantes  Bathyphantes gracilis       4598
#                                       Tetragnathidae   Pachygnatha   Pachygnatha degeeri         4500
#           Chordata    Actinopterygii  Scombridae       Thunnus       Thunnus albacares           4461
#           Arthropoda  Insecta         Coenagrionidae   Coenagrion    Coenagrion puella           4373
# Name: species, dtype: int64

# %% [markdown]
# Let's create a map with the number of unique species per country. First, we'll group by country code and compute the number of unique species (per country).

# %%
species_per_country = chunk.groupby("countrycode").species.nunique()
species_per_country
# Out:
# countrycode
# AD      0
# AE      1
# AF      2
# AG      0
# AL      1
#      ...
# YE     14
# YT     11
# ZA    116
# ZM      2
# ZW     12
# Name: species, Length: 204, dtype: int64

# %% [markdown]
# Finally, we can plot the counts on a map using geopandas, by joining `species_per_country` to a dataset with country boundaries.

# %%
import geopandas
import cartopy

countries = geopandas.read_file(
    "https://raw.githubusercontent.com/datasets/geo-countries/master/data/countries.geojson"
)
gdf = geopandas.GeoDataFrame(
    countries.merge(species_per_country, left_on="ISO_A2", right_index=True)
)
crs = cartopy.crs.Robinson()
ax = gdf.to_crs(crs.proj4_init).plot(
    column="species", legend=True, scheme="natural_breaks", k=5, figsize=(15, 15)
)
ax.set_axis_off()

# %% [markdown]
# ### Working with the full dataset
#
# Thus far, we've just used a single partition from the full GBIF dataset. All of the examples shown in this notebook work on the entire dataset using `dask.dataframe` to read in the Parquet dataset.
#
# You might want create a cluster to process the data in parallel on many machines.
#
# ```python
# from dask_gateway import GatewayCluster
#
# cluster = GatewayCluster()
# cluster.scale(16)
# client = cluster.get_client()
# ```
#
# Then use `dask.dataframe.read_parquet` to read in the files. To speed things up even more, we'll specify a subset of files to read in.
#
# ```python
# df = dd.read_parquet(
#     signed_asset.href,
#     columns=["countrycode", "species"],
#     storage_options=signed_asset.extra_fields["table:storage_options"],
# )
# ```
#
# Now you can repeat the computations above, replacing `chunk` with `df`.
#
# ### Next Steps
#
# Now that you've an introduction to the Forest Inventory and Analysis dataset, learn more with
#
# * The [Reading tabular data quickstart](https://planetarycomputer.microsoft.com/docs/quickstarts/reading-tabular-data/) for an introduction to tabular data on the Planeatry Computer
# * [Scale with Dask](https://planetarycomputer.microsoft.com/docs/quickstarts/scale-with-dask/) for more on using Dask to work with large datasets

# %%
from dask_gateway import GatewayCluster

cluster = GatewayCluster()
cluster.scale(16)
client = cluster.get_client()

client
# Out:
# <Client: 'tls://10.244.56.24:8786' processes=0 threads=0, memory=0 B>

# %%
df = dd.read_parquet(
    signed_asset.href,
    columns=["countrycode", "species"],
    storage_options=signed_asset.extra_fields["table:storage_options"],
    dataset={"require_extension": None},
)

# %%
species_per_country = df.groupby("countrycode").species.nunique()
# Out:
# countrycode
# AD    1460
# AE    1998
# AF    2344
# AG    1471
# AL    3376
# Name: species, dtype: int64

# %%
species_per_country_df = species_per_country.compute()

# %%
chunk.columns
# Out:
# Index(['gbifid', 'datasetkey', 'occurrenceid', 'kingdom', 'phylum', 'class',
#        'order', 'family', 'genus', 'species', 'infraspecificepithet',
#        'taxonrank', 'scientificname', 'verbatimscientificname',
#        'verbatimscientificnameauthorship', 'countrycode', 'locality',
#        'stateprovince', 'occurrencestatus', 'individualcount',
#        'publishingorgkey', 'decimallatitude', 'decimallongitude',
#        'coordinateuncertaintyinmeters', 'coordinateprecision', 'elevation',
#        'elevationaccuracy', 'depth', 'depthaccuracy', 'eventdate', 'day',
#        'month', 'year', 'taxonkey', 'specieskey', 'basisofrecord',
#        'institutioncode', 'collectioncode', 'catalognumber', 'recordnumber',
#        'identifiedby', 'dateidentified', 'license', 'rightsholder',
#        'recordedby', 'typestatus', 'establishmentmeans', 'lastinterpreted',
#        'mediatype', 'issue'],
#       dtype='object')

# %%
importcolumnstplotlib.pyplot as plt  

plt.hist(species_per_country_df)
# Out:
# (array([209.,  23.,  12.,   4.,   1.,   0.,   0.,   1.,   0.,   1.]),
#  array([5.300000e+01, 1.924490e+04, 3.843680e+04, 5.762870e+04,
#         7.682060e+04, 9.601250e+04, 1.152044e+05, 1.343963e+05,
#         1.535882e+05, 1.727801e+05, 1.919720e+05]),
#  <BarContainer object of 10 artists>)

# %%
countries = geopandas.read_file(
    "https://raw.githubusercontent.com/datasets/geo-countries/master/data/countries.geojson"
)
gdf = geopandas.GeoDataFrame(
    countries.merge(species_per_country_df, left_on="ISO_A2", right_index=True)
)
crs = cartopy.crs.Robinson()
ax = gdf.to_crs(crs.proj4_init).plot(
    column="species", legend=True, scheme="natural_breaks", k=10, figsize=(15, 15)
)
ax.set_axis_off()
